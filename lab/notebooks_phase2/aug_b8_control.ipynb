# %% [markdown]
# # control b8

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchtext import data
import pandas as pd
import unicodedata
import string
import re
import random
import copy
from contra_qa.plots.functions  import simple_step_plot, plot_confusion_matrix
import  matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from nltk.translate.bleu_score import sentence_bleu


% matplotlib inline

# %% [markdown]
# ### Preparing data

# %%
df2 = pd.read_csv("data/boolean8_train.csv")
df2_test = pd.read_csv("data/boolean8_test.csv")

df2["text"] = df2["sentence1"] + df2["sentence2"] 
df2_test["text"] = df2_test["sentence1"] + df2_test["sentence2"] 

all_sentences = list(df2.text.values) + list(df2_test.text.values)

df2train = df2

# %%
df2train.tail()
# Out:
#                                               sentence1  \
# 9995  Nigeria or Brazil are in the geopolitical posi...
# 9996  Nigeria or Mexico got to the quarter finals la...
# 9997  Mexico or England got to the quarter finals la...
# 9998  Denmark or Costa Rica are in the geopolitical ...
# 9999                    Gilbert has visited Dej or Arad
#
#                                               sentence2  \
# 9995  Nigeria isn't in the geopolitical position of ...
# 9996   neither Nigeria nor Morocco got to the quarte...
# 9997   neither Switzerland  nor Mexico got to the qu...
# 9998  Denmark isn't in the geopolitical position of ...
# 9999            Gilbert visited neither Reghin nor Arad
#
#                                                    or_A  \
# 9995  Nigeria is in the geopolitical position of Russia
# 9996        Nigeria got to the quarter finals last year
# 9997         Mexico got to the quarter finals last year
# 9998  Denmark is in the geopolitical position of Uru...
# 9999                            Gilbert has visited Dej
#
#                                                    or_B  label  \
# 9995   Brazil is in the geopolitical position of Russia      1
# 9996         Mexico got to the quarter finals last year      0
# 9997        England got to the quarter finals last year      0
# 9998  Costa Rica is in the geopolitical position of ...      1
# 9999                           Gilbert has visited Arad      0
#
#                                                    text
# 9995  Nigeria or Brazil are in the geopolitical posi...
# 9996  Nigeria or Mexico got to the quarter finals la...
# 9997  Mexico or England got to the quarter finals la...
# 9998  Denmark or Costa Rica are in the geopolitical ...
# 9999  Gilbert has visited Dej or AradGilbert visited...

# %%
# Turn a Unicode string to plain ASCII, thanks to
# http://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

# Lowercase, trim, and remove non-letter characters

def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s


example = "ddddda'''~~çãpoeéééééÈ'''#$$##@!@!@AAS@#12323fdf"
print("Before:", example)
print()
print("After:", normalizeString(example))
# Out:
# Before: ddddda'''~~çãpoeéééééÈ'''#$$##@!@!@AAS@#12323fdf
#
# After: ddddda capoeeeeeee ! ! aas fdf

# %%
df2train.or_A = df2train.or_A.map(normalizeString)
df2train.or_B = df2train.or_B.map(normalizeString)

# %%
df2train.tail()
# Out:
#                                               sentence1  \
# 9995  Nigeria or Brazil are in the geopolitical posi...
# 9996  Nigeria or Mexico got to the quarter finals la...
# 9997  Mexico or England got to the quarter finals la...
# 9998  Denmark or Costa Rica are in the geopolitical ...
# 9999                    Gilbert has visited Dej or Arad
#
#                                               sentence2  \
# 9995  Nigeria isn't in the geopolitical position of ...
# 9996   neither Nigeria nor Morocco got to the quarte...
# 9997   neither Switzerland  nor Mexico got to the qu...
# 9998  Denmark isn't in the geopolitical position of ...
# 9999            Gilbert visited neither Reghin nor Arad
#
#                                                    or_A  \
# 9995  nigeria is in the geopolitical position of russia
# 9996        nigeria got to the quarter finals last year
# 9997         mexico got to the quarter finals last year
# 9998  denmark is in the geopolitical position of uru...
# 9999                            gilbert has visited dej
#
#                                                    or_B  label  \
# 9995   brazil is in the geopolitical position of russia      1
# 9996         mexico got to the quarter finals last year      0
# 9997        england got to the quarter finals last year      0
# 9998  costa rica is in the geopolitical position of ...      1
# 9999                           gilbert has visited arad      0
#
#                                                    text
# 9995  Nigeria or Brazil are in the geopolitical posi...
# 9996  Nigeria or Mexico got to the quarter finals la...
# 9997  Mexico or England got to the quarter finals la...
# 9998  Denmark or Costa Rica are in the geopolitical ...
# 9999  Gilbert has visited Dej or AradGilbert visited...

# %%
df2train["sentence1_p"] = df2train["or_A"] + " or " + df2train["or_B"]

# %%
df2train.head()
# Out:
#                                            sentence1  \
# 0  England or Japan got to the quarter finals las...
# 1                  Glenda has visited Craiova or Dej
# 2            Poland or Russia won the last world cup
# 3                Kimberly traveled to Tulcea or Blaj
# 4           Tunisia or Russia won the last world cup
#
#                                            sentence2  \
# 0   neither Peru nor England got to the quarter f...
# 1  Glenda didn't visit Craiova and Glenda didn't ...
# 2   neither Poland nor Russia won the last world cup
# 3  Kimberly didn't travel to Tulcea and Kimberly ...
# 4  Tunisia didn't win the last world cup and Russ...
#
#                                           or_A  \
# 0  england got to the quarter finals last year
# 1                   glenda has visited craiova
# 2                poland won the last world cup
# 3              kimberly has traveled to tulcea
# 4               tunisia won the last world cup
#
#                                         or_B  label  \
# 0  japan got to the quarter finals last year      0
# 1                     glenda has visited dej      1
# 2              russia won the last world cup      1
# 3              kimberly has traveled to blaj      1
# 4              russia won the last world cup      1
#
#                                                 text  \
# 0  England or Japan got to the quarter finals las...
# 1  Glenda has visited Craiova or DejGlenda didn't...
# 2  Poland or Russia won the last world cup neithe...
# 3  Kimberly traveled to Tulcea or BlajKimberly di...
# 4  Tunisia or Russia won the last world cupTunisi...
#
#                                          sentence1_p
# 0  england got to the quarter finals last year or...
# 1  glenda has visited craiova or glenda has visit...
# 2  poland won the last world cup or russia won th...
# 3  kimberly has traveled to tulcea or kimberly ha...
# 4  tunisia won the last world cup or russia won t...

# %%
df2train_plus = df2train[["sentence1_p", "sentence2", "label"]]

df2train_plus.sentence2 = df2train_plus.sentence2.map(normalizeString)
df2train_plus.rename(columns={"sentence1_p": "sentence1"}, inplace=True)
# Out:
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df2train_plus.to_csv("data/boolean8_control_train.csv", index=False)

# %% [markdown]
# ## generating new data for test

# %%
df2_test.or_A = df2_test.or_A.map(normalizeString)
df2_test.or_B = df2_test.or_B.map(normalizeString)

# %%
df2_test["sentence1_p"] = df2_test["or_A"] + " or " + df2_test["or_B"]

# %%
df2_test.head()
# Out:
#                                            sentence1  \
# 0                      Jessica went to Reghin or Dej
# 1  Korea Republic or Argentina are in the geopoli...
# 2               Victoria went to Giurgiu or Mangalia
# 3  Mexico or Iran are in the geopolitical positio...
# 4  Panama or Nigeria are in the geopolitical posi...
#
#                                            sentence2  \
# 0                        Jessica didn't go to Reghin
# 1   neither Korea Republic nor Russia are in the ...
# 2  Victoria didn't go to Giurgiu and Victoria did...
# 3   neither Mexico nor Iran are in the geopolitic...
# 4   neither Panama nor Nigeria are in the geopoli...
#
#                                                 or_A  \
# 0                             jessica went to reghin
# 1  korea republic is in the geopolitical position...
# 2                           victoria went to giurgiu
# 3   mexico is in the geopolitical position of serbia
# 4  panama is in the geopolitical position of tunisia
#
#                                                 or_B  label  \
# 0                                jessica went to dej      0
# 1  argentina is in the geopolitical position of s...      0
# 2                          victoria went to mangalia      1
# 3     iran is in the geopolitical position of serbia      1
# 4  nigeria is in the geopolitical position of tun...      1
#
#                                                 text  \
# 0  Jessica went to Reghin or DejJessica didn't go...
# 1  Korea Republic or Argentina are in the geopoli...
# 2  Victoria went to Giurgiu or MangaliaVictoria d...
# 3  Mexico or Iran are in the geopolitical positio...
# 4  Panama or Nigeria are in the geopolitical posi...
#
#                                          sentence1_p
# 0      jessica went to reghin or jessica went to dej
# 1  korea republic is in the geopolitical position...
# 2  victoria went to giurgiu or victoria went to m...
# 3  mexico is in the geopolitical position of serb...
# 4  panama is in the geopolitical position of tuni...

# %%
df2_test_plus = df2_test[["sentence1_p", "sentence2", "label"]]

df2_test_plus.sentence2 = df2_test_plus.sentence2.map(normalizeString)
df2_test_plus.rename(columns={"sentence1_p": "sentence1"}, inplace=True)
# Out:
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df2_test_plus.head()
# Out:
#                                            sentence1  \
# 0      jessica went to reghin or jessica went to dej
# 1  korea republic is in the geopolitical position...
# 2  victoria went to giurgiu or victoria went to m...
# 3  mexico is in the geopolitical position of serb...
# 4  panama is in the geopolitical position of tuni...
#
#                                            sentence2  label
# 0                        jessica didn t go to reghin      0
# 1  neither korea republic nor russia are in the g...      0
# 2  victoria didn t go to giurgiu and victoria did...      1
# 3  neither mexico nor iran are in the geopolitica...      1
# 4  neither panama nor nigeria are in the geopolit...      1

# %%
df2_test_plus.to_csv("data/boolean8_control_test.csv", index=False)
