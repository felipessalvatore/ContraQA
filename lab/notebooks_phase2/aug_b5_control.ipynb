# %% [markdown]
# # control: b5 dataset

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchtext import data
import pandas as pd
import unicodedata
import string
import re
import random
import copy
from contra_qa.plots.functions  import simple_step_plot, plot_confusion_matrix
import  matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from nltk.translate.bleu_score import sentence_bleu


% matplotlib inline

# %% [markdown]
# ### Preparing data

# %%
df2 = pd.read_csv("data/boolean5_train.csv")
df2_test = pd.read_csv("data/boolean5_test.csv")

df2["text"] = df2["sentence1"] + df2["sentence2"] 
df2_test["text"] = df2_test["sentence1"] + df2_test["sentence2"] 

all_sentences = list(df2.text.values) + list(df2_test.text.values)

df2train = df2

# %%
df2train.tail()
# Out:
#                                               sentence1  \
# 9995  Kristin created a victorious and ashy work of art
# 9996         Doris created an ashy and easy work of art
# 9997       Dawn created a shapely and plain work of art
# 9998     Gertrude created an ugly and eager work of art
# 9999  Elizabeth created a gifted and worried work of...
#
#                                             sentence2  \
# 9995   Kristin didn't create a victorious work of art
# 9996          Wendy didn't create an easy work of art
# 9997          Wilma didn't create a plain work of art
# 9998       Gertrude didn't create an ugly work of art
# 9999     Elizabeth didn't create a gifted work of art
#
#                                          and_A  \
# 9995  Kristin created a victorious work of art
# 9996         Doris created an ashy work of art
# 9997        Dawn created a shapely work of art
# 9998      Gertrude created an ugly work of art
# 9999    Elizabeth created a gifted work of art
#
#                                         and_B  label  \
# 9995      Kristin created an ashy work of art      1
# 9996        Doris created an easy work of art      0
# 9997         Dawn created a plain work of art      0
# 9998    Gertrude created an eager work of art      1
# 9999  Elizabeth created a worried work of art      1
#
#                                                    text
# 9995  Kristin created a victorious and ashy work of ...
# 9996  Doris created an ashy and easy work of art Wen...
# 9997  Dawn created a shapely and plain work of art W...
# 9998  Gertrude created an ugly and eager work of art...
# 9999  Elizabeth created a gifted and worried work of...

# %%
# Turn a Unicode string to plain ASCII, thanks to
# http://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

# Lowercase, trim, and remove non-letter characters

def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s


example = "ddddda'''~~çãpoeéééééÈ'''#$$##@!@!@AAS@#12323fdf"
print("Before:", example)
print()
print("After:", normalizeString(example))
# Out:
# Before: ddddda'''~~çãpoeéééééÈ'''#$$##@!@!@AAS@#12323fdf
#
# After: ddddda capoeeeeeee ! ! aas fdf

# %%
df2train.and_A = df2train.and_A.map(normalizeString)
df2train.and_B = df2train.and_B.map(normalizeString)

# %%
df2train.tail()
# Out:
#                                               sentence1  \
# 9995  Kristin created a victorious and ashy work of art
# 9996         Doris created an ashy and easy work of art
# 9997       Dawn created a shapely and plain work of art
# 9998     Gertrude created an ugly and eager work of art
# 9999  Elizabeth created a gifted and worried work of...
#
#                                             sentence2  \
# 9995   Kristin didn't create a victorious work of art
# 9996          Wendy didn't create an easy work of art
# 9997          Wilma didn't create a plain work of art
# 9998       Gertrude didn't create an ugly work of art
# 9999     Elizabeth didn't create a gifted work of art
#
#                                          and_A  \
# 9995  kristin created a victorious work of art
# 9996         doris created an ashy work of art
# 9997        dawn created a shapely work of art
# 9998      gertrude created an ugly work of art
# 9999    elizabeth created a gifted work of art
#
#                                         and_B  label  \
# 9995      kristin created an ashy work of art      1
# 9996        doris created an easy work of art      0
# 9997         dawn created a plain work of art      0
# 9998    gertrude created an eager work of art      1
# 9999  elizabeth created a worried work of art      1
#
#                                                    text
# 9995  Kristin created a victorious and ashy work of ...
# 9996  Doris created an ashy and easy work of art Wen...
# 9997  Dawn created a shapely and plain work of art W...
# 9998  Gertrude created an ugly and eager work of art...
# 9999  Elizabeth created a gifted and worried work of...

# %%
df2train["sentence1_p"] = df2train["and_A"] + " and " + df2train["and_B"]

# %%
df2train.head()
# Out:
#                                            sentence1  \
# 0       Jeffery created a silly and vast work of art
# 1     Hilda created a zealous and better work of art
# 2    Cheryl created an ugly and obedient work of art
# 3        Hector created a plump and bald work of art
# 4  Madeline created a lemon and important work of...
#
#                                        sentence2  \
# 0      Jeffery didn't create a silly work of art
# 1      Hilda didn't create a zealous work of art
# 2       Cheryl didn't create an ugly work of art
# 3       Hector didn't create a plump work of art
# 4   Madeline didn't create a careful work of art
#
#                                   and_A  \
# 0   jeffery created a silly work of art
# 1   hilda created a zealous work of art
# 2    cheryl created an ugly work of art
# 3    hector created a plump work of art
# 4  madeline created a lemon work of art
#
#                                        and_B  label  \
# 0         jeffery created a vast work of art      1
# 1         hilda created a better work of art      1
# 2     cheryl created an obedient work of art      1
# 3          hector created a bald work of art      1
# 4  madeline created an important work of art      0
#
#                                                 text  \
# 0  Jeffery created a silly and vast work of art J...
# 1  Hilda created a zealous and better work of art...
# 2  Cheryl created an ugly and obedient work of ar...
# 3  Hector created a plump and bald work of art He...
# 4  Madeline created a lemon and important work of...
#
#                                          sentence1_p
# 0  jeffery created a silly work of art and jeffer...
# 1  hilda created a zealous work of art and hilda ...
# 2  cheryl created an ugly work of art and cheryl ...
# 3  hector created a plump work of art and hector ...
# 4  madeline created a lemon work of art and madel...

# %%
df2train_plus = df2train[["sentence1_p", "sentence2", "label"]]

df2train_plus.sentence2 = df2train_plus.sentence2.map(normalizeString)
df2train_plus.rename(columns={"sentence1_p": "sentence1"}, inplace=True)
# Out:
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df2train_plus.head()
# Out:
#                                            sentence1  \
# 0  jeffery created a silly work of art and jeffer...
# 1  hilda created a zealous work of art and hilda ...
# 2  cheryl created an ugly work of art and cheryl ...
# 3  hector created a plump work of art and hector ...
# 4  madeline created a lemon work of art and madel...
#
#                                       sentence2  label
# 0     jeffery didn t create a silly work of art      1
# 1     hilda didn t create a zealous work of art      1
# 2      cheryl didn t create an ugly work of art      1
# 3      hector didn t create a plump work of art      1
# 4  madeline didn t create a careful work of art      0

# %%
df2train_plus.to_csv("data/boolean5_control_train.csv", index=False)

# %% [markdown]
# ## generating new data for test

# %%
df2_test.and_A = df2_test.and_A.map(normalizeString)
df2_test.and_B = df2_test.and_B.map(normalizeString)

# %%
df2_test["sentence1_p"] = df2_test["and_A"] + " and " + df2_test["and_B"]

# %%
df2_test.head()
# Out:
#                                            sentence1  \
# 0        Jared created an ashy and witty work of art
# 1        Patricia created a calm and icy work of art
# 2  Elsie created a beautiful and gorgeous work of...
# 3  Herbert created a mysterious and worried work ...
# 4   Janice created an easy and agreeable work of art
#
#                                          sentence2  \
# 0      Alexander didn't create an ashy work of art
# 1        Patricia didn't create a calm work of art
# 2      Juana didn't create a beautiful work of art
# 3   Herbert didn't create a mysterious work of art
# 4         Janice didn't create an easy work of art
#
#                                       and_A  \
# 0         jared created an ashy work of art
# 1       patricia created a calm work of art
# 2     elsie created a beautiful work of art
# 3  herbert created a mysterious work of art
# 4        janice created an easy work of art
#
#                                      and_B  label  \
# 0        jared created a witty work of art      0
# 1      patricia created an icy work of art      1
# 2     elsie created a gorgeous work of art      0
# 3    herbert created a worried work of art      1
# 4  janice created an agreeable work of art      1
#
#                                                 text  \
# 0  Jared created an ashy and witty work of art Al...
# 1  Patricia created a calm and icy work of art Pa...
# 2  Elsie created a beautiful and gorgeous work of...
# 3  Herbert created a mysterious and worried work ...
# 4  Janice created an easy and agreeable work of a...
#
#                                          sentence1_p
# 0  jared created an ashy work of art and jared cr...
# 1  patricia created a calm work of art and patric...
# 2  elsie created a beautiful work of art and elsi...
# 3  herbert created a mysterious work of art and h...
# 4  janice created an easy work of art and janice ...

# %%
df2_test_plus = df2_test[["sentence1_p", "sentence2", "label"]]

df2_test_plus.sentence2 = df2_test_plus.sentence2.map(normalizeString)
df2_test_plus.rename(columns={"sentence1_p": "sentence1"}, inplace=True)
# Out:
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df2_test_plus.head()
# Out:
#                                            sentence1  \
# 0  jared created an ashy work of art and jared cr...
# 1  patricia created a calm work of art and patric...
# 2  elsie created a beautiful work of art and elsi...
# 3  herbert created a mysterious work of art and h...
# 4  janice created an easy work of art and janice ...
#
#                                         sentence2  label
# 0     alexander didn t create an ashy work of art      0
# 1       patricia didn t create a calm work of art      1
# 2     juana didn t create a beautiful work of art      0
# 3  herbert didn t create a mysterious work of art      1
# 4        janice didn t create an easy work of art      1

# %%
df2_test_plus.to_csv("data/boolean5_control_test.csv", index=False)
