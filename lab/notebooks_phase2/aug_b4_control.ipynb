# %% [markdown]
# # Add model: translation attention ecoder-decocer over the b4 dataset

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchtext import data
import pandas as pd
import unicodedata
import string
import re
import random
import copy
from contra_qa.plots.functions  import simple_step_plot, plot_confusion_matrix
import  matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from nltk.translate.bleu_score import sentence_bleu


% matplotlib inline

# %% [markdown]
# ### Preparing data

# %%
df2 = pd.read_csv("data/boolean4_train.csv")
df2_test = pd.read_csv("data/boolean4_test.csv")

df2["text"] = df2["sentence1"] + df2["sentence2"] 
df2_test["text"] = df2_test["sentence1"] + df2_test["sentence2"] 

all_sentences = list(df2.text.values) + list(df2_test.text.values)

df2train = df2

# %%
df2train.tail()
# Out:
#                                               sentence1  \
# 9995  Lynn drew ahead of the other runners and felt ...
# 9996  Crystal slept for eight hours and dreamed of r...
# 9997  Wallace lost Alberto's green car and showed Kr...
# 9998  Shelly put Beverly in charge and burned Chad's...
# 9999       Daisy ate an apple and chose to live in Blaj
#
#                                           sentence2  \
# 9995  Billie didn't draw ahead of the other runners
# 9996                         Crystal didn't see him
# 9997           Alex didn't lose Alberto's green car
# 9998                Shelly didn't burn Chad's house
# 9999            Daisy didn't choose to live in Blaj
#
#                                      and_A  \
# 9995  Lynn drew ahead of the other runners
# 9996         Crystal slept for eight hours
# 9997      Wallace lost Alberto's green car
# 9998          Shelly put Beverly in charge
# 9999                    Daisy ate an apple
#
#                                     and_B  label  \
# 9995                Lynn felt an outsider      0
# 9996  Crystal dreamed of running in Lugoj      0
# 9997  Wallace showed Kristen's old photos      0
# 9998           Shelly burned Chad's house      1
# 9999          Daisy chose to live in Blaj      1
#
#                                                    text
# 9995  Lynn drew ahead of the other runners and felt ...
# 9996  Crystal slept for eight hours and dreamed of r...
# 9997  Wallace lost Alberto's green car and showed Kr...
# 9998  Shelly put Beverly in charge and burned Chad's...
# 9999  Daisy ate an apple and chose to live in BlajDa...

# %%
# Turn a Unicode string to plain ASCII, thanks to
# http://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

# Lowercase, trim, and remove non-letter characters

def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s


example = "ddddda'''~~çãpoeéééééÈ'''#$$##@!@!@AAS@#12323fdf"
print("Before:", example)
print()
print("After:", normalizeString(example))
# Out:
# Before: ddddda'''~~çãpoeéééééÈ'''#$$##@!@!@AAS@#12323fdf
#
# After: ddddda capoeeeeeee ! ! aas fdf

# %%
df2train.and_A = df2train.and_A.map(normalizeString)
df2train.and_B = df2train.and_B.map(normalizeString)

# %%
df2train.tail()
# Out:
#                                               sentence1  \
# 9995  Lynn drew ahead of the other runners and felt ...
# 9996  Crystal slept for eight hours and dreamed of r...
# 9997  Wallace lost Alberto's green car and showed Kr...
# 9998  Shelly put Beverly in charge and burned Chad's...
# 9999       Daisy ate an apple and chose to live in Blaj
#
#                                           sentence2  \
# 9995  Billie didn't draw ahead of the other runners
# 9996                         Crystal didn't see him
# 9997           Alex didn't lose Alberto's green car
# 9998                Shelly didn't burn Chad's house
# 9999            Daisy didn't choose to live in Blaj
#
#                                      and_A  \
# 9995  lynn drew ahead of the other runners
# 9996         crystal slept for eight hours
# 9997      wallace lost alberto s green car
# 9998          shelly put beverly in charge
# 9999                    daisy ate an apple
#
#                                     and_B  label  \
# 9995                lynn felt an outsider      0
# 9996  crystal dreamed of running in lugoj      0
# 9997  wallace showed kristen s old photos      0
# 9998           shelly burned chad s house      1
# 9999          daisy chose to live in blaj      1
#
#                                                    text
# 9995  Lynn drew ahead of the other runners and felt ...
# 9996  Crystal slept for eight hours and dreamed of r...
# 9997  Wallace lost Alberto's green car and showed Kr...
# 9998  Shelly put Beverly in charge and burned Chad's...
# 9999  Daisy ate an apple and chose to live in BlajDa...

# %%
df2train["sentence1_p"] = df2train["and_A"] + " and " + df2train["and_B"]

# %%
df2train.head()
# Out:
#                                            sentence1  \
# 0       Reginald caught a mango fish and ran from me
# 1  Sandy thought I was living in Craiova and grew...
# 2   Brenda burned Chris's house and let use this pen
# 3     Brenda sold Josephine's house and ate an apple
# 4                  Tamara fell off and hung up on me
#
#                                     sentence2  \
# 0          Reginald didn't catch a mango fish
# 1  Sandy didn't think I was living in Craiova
# 2              Brenda didn't let use this pen
# 3                  Brenda didn't eat an apple
# 4                  Tamara didn't ring from me
#
#                                    and_A                    and_B  label  \
# 0           reginald caught a mango fish     reginald ran from me      1
# 1  sandy thought i was living in craiova    sandy grew up in jail      1
# 2            brenda burned chris s house  brenda let use this pen      1
# 3          brenda sold josephine s house      brenda ate an apple      1
# 4                        tamara fell off     tamara hung up on me      0
#
#                                                 text  \
# 0  Reginald caught a mango fish and ran from meRe...
# 1  Sandy thought I was living in Craiova and grew...
# 2  Brenda burned Chris's house and let use this p...
# 3  Brenda sold Josephine's house and ate an apple...
# 4  Tamara fell off and hung up on meTamara didn't...
#
#                                          sentence1_p
# 0  reginald caught a mango fish and reginald ran ...
# 1  sandy thought i was living in craiova and sand...
# 2  brenda burned chris s house and brenda let use...
# 3  brenda sold josephine s house and brenda ate a...
# 4           tamara fell off and tamara hung up on me

# %%
df2train_plus = df2train[["sentence1_p", "sentence2", "label"]]

df2train_plus.sentence2 = df2train_plus.sentence2.map(normalizeString)
df2train_plus.rename(columns={"sentence1_p": "sentence1"}, inplace=True)
# Out:
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df2train_plus.head()
# Out:
#                                            sentence1  \
# 0  reginald caught a mango fish and reginald ran ...
# 1  sandy thought i was living in craiova and sand...
# 2  brenda burned chris s house and brenda let use...
# 3  brenda sold josephine s house and brenda ate a...
# 4           tamara fell off and tamara hung up on me
#
#                                     sentence2  label
# 0          reginald didn t catch a mango fish      1
# 1  sandy didn t think i was living in craiova      1
# 2              brenda didn t let use this pen      1
# 3                  brenda didn t eat an apple      1
# 4                  tamara didn t ring from me      0

# %%
df2train_plus.to_csv("data/boolean4_control_train.csv", index=False)

# %% [markdown]
# ## generating new data for test

# %%
df2_test.and_A = df2_test.and_A.map(normalizeString)
df2_test.and_B = df2_test.and_B.map(normalizeString)

# %%
df2_test["sentence1_p"] = df2_test["and_A"] + " and " + df2_test["and_B"]

# %%
df2_test.head()
# Out:
#                                            sentence1  \
# 0  Seth broke the rules and knew Antoinette's secret
# 1       Joy lent me Gerald's icy bicycle and blew it
# 2                    Arlene grew up and ate an apple
# 3     Beverly met him and froze Juana's bank account
# 4                Julie beat her and sang a nice song
#
#                                        sentence2  \
# 0           Seth didn't know Antoinette's secret
# 1    Frances didn't lend me Gerald's icy bicycle
# 2                    Arlene didn't hang up on me
# 3  Antoinette didn't freeze Juana's bank account
# 4                          Elmer didn't beat her
#
#                               and_A                               and_B  \
# 0              seth broke the rules       seth knew antoinette s secret
# 1  joy lent me gerald s icy bicycle                         joy blew it
# 2                    arlene grew up                 arlene ate an apple
# 3                   beverly met him  beverly froze juana s bank account
# 4                    julie beat her              julie sang a nice song
#
#    label                                               text  \
# 0      1  Seth broke the rules and knew Antoinette's sec...
# 1      0  Joy lent me Gerald's icy bicycle and blew itFr...
# 2      0  Arlene grew up and ate an appleArlene didn't h...
# 3      0  Beverly met him and froze Juana's bank account...
# 4      0  Julie beat her and sang a nice songElmer didn'...
#
#                                          sentence1_p
# 0  seth broke the rules and seth knew antoinette ...
# 1   joy lent me gerald s icy bicycle and joy blew it
# 2             arlene grew up and arlene ate an apple
# 3  beverly met him and beverly froze juana s bank...
# 4          julie beat her and julie sang a nice song

# %%
df2_test_plus = df2_test[["sentence1_p", "sentence2", "label"]]

df2_test_plus.sentence2 = df2_test_plus.sentence2.map(normalizeString)
df2_test_plus.rename(columns={"sentence1_p": "sentence1"}, inplace=True)
# Out:
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/felsal/.local/lib/python3.5/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df2_test_plus.head()
# Out:
#                                            sentence1  \
# 0  seth broke the rules and seth knew antoinette ...
# 1   joy lent me gerald s icy bicycle and joy blew it
# 2             arlene grew up and arlene ate an apple
# 3  beverly met him and beverly froze juana s bank...
# 4          julie beat her and julie sang a nice song
#
#                                        sentence2  label
# 0           seth didn t know antoinette s secret      1
# 1    frances didn t lend me gerald s icy bicycle      0
# 2                    arlene didn t hang up on me      0
# 3  antoinette didn t freeze juana s bank account      0
# 4                          elmer didn t beat her      0

# %%
df2_test_plus.to_csv("data/boolean4_control_test.csv", index=False)
